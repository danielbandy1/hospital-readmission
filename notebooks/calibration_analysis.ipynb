# %% [markdown]
# # Calibration Analysis
#
# This notebook compares the current XGBoost readmission model's raw probabilities against an isotonic calibration layer.

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path('..').resolve()))
import json
from pathlib import Path
metrics = json.loads(Path('../reports/calibration_metrics.json').read_text())
metrics

# %% [markdown]
# ## Interpretation
#
# Brier score and ECE evaluate probability quality, not just ranking. A lower value after isotonic calibration means the score is better aligned with observed readmission rates.

# %%
from IPython.display import Image, display
display(Image('../reports/figures/calibration_curve.png'))
